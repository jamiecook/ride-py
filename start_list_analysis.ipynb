# %% [markdown]
# # Race start list analysis

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
from start_list import plot_race

pd.set_option('display.max_rows', 500)

df = plot_race(27206)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ['MMA' 'MMB' 'MMC' 'MMD' 'U17' 'WA' 'WD']

# %% [markdown]
# Now lets look at the actual table and see who all those orange riders are

# %%
def highlight_row(row):
    color = 'background-color: red' if "Hope" in row['club']  else ''
    return color

# Apply style to the 'Status' column, color entire row based on string value
highlighted_rows = np.where(df['team'].str.contains("Hope"),
                            'background-color: #f39d1d; color: white',
                            '')
display(df.style.apply( lambda _: highlighted_rows))
# Out:
# <style type="text/css">
# ...

# %%
df.team.unique()
df.groupby('team').size().sort_values(ascending=False)
# Out:
# team
# Hope                               15
# Hamilton                           11
# WattBomb                           10
# Lifecycle                           6
# WCDI                                5
# UQCC                                4
# BNECC                               4
# Balmoral                            2
# Clevr Racing                        2
# Ipswich CC                          1
# Bendigo & District Cycling Club     1
# Darling Downs CC                    1
# SunnyCoast                          1
# Lifecyle                            1
# KPCC                                1
# WolfTeam                            1
# dtype: int64
